# %%
# import all that require
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from mpl_toolkits.mplot3d import Axes3D

# %%
# Prediction with regression linear
df = pd.read_csv('ds_salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                 job_title
# 0       2023               SE              FT  Principal Data Scientist  \
# 1       2023               MI              CT               ML Engineer
# 2       2023               MI              CT               ML Engineer
# 3       2023               SE              FT            Data Scientist
# 4       2023               SE              FT            Data Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio
# 0   80000             EUR          85847                 ES           100  \
# 1   30000             USD          30000                 US           100
# 2   25500             USD          25500                 US           100
# 3  175000             USD         175000                 CA           100
# 4  120000             USD         120000                 CA           100
#
#   company_location company_size
# 0               ES            L
# ...

# %%
#filter the data for job_title do Data Science
Data_Scientist = df[df['job_title'] == 'Data Scientist']
print(Data_Scientist)
# Out:
#       work_year experience_level employment_type       job_title  salary
# 3          2023               SE              FT  Data Scientist  175000  \
# 4          2023               SE              FT  Data Scientist  120000
# 7          2023               SE              FT  Data Scientist  219000
# 8          2023               SE              FT  Data Scientist  141000
# 9          2023               SE              FT  Data Scientist  147100
# ...         ...              ...             ...             ...     ...
# 3741       2020               MI              FT  Data Scientist  118000
# 3742       2020               MI              FT  Data Scientist  138350
# 3746       2021               MI              FT  Data Scientist  160000
# 3750       2020               SE              FT  Data Scientist  412000
# 3752       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio
# ...

# %%
work_year = Data_Scientist['work_year']
salary_in_usd = Data_Scientist['salary_in_usd']

# %%
x = np.array(salary_in_usd).reshape(-1, 1)
y = np.array(work_year)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=20, random_state=42)

# %%
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_prediction = regression.predict(x_train)
mse = mean_squared_error(y_train, y_prediction)
print("Mean Squared Error:", mse)

prediction = regression.predict(x_test)
# Out:
# Mean Squared Error: 0.4315798991176968

# %%
# melihat perbandingan harga antara Data possible salary data science
plt.scatter(x_train, y_train, color='blue')
plt.plot(x_train, regression.predict(x_train), color = 'red')
plt.title("Data Science possible salary")
plt.xlabel('year')
plt.ylabel('Salary in USD')
plt.show()

plt.scatter(x_test, y_test, color='blue')
plt.plot(x_train, regression.predict(x_train), color = 'red')
plt.title("Data Science possible salary")
plt.xlabel('year')
plt.ylabel('Salary in USD')
plt.show()
